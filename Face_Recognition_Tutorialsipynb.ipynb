# %% [markdown]
# <a href="https://colab.research.google.com/github/plaban1981/face_recognition/blob/main/Face_Recognition_Tutorialsipynb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Find faces in pictures using face_recognition library

# %%
# !pip install face-recognition
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting face-recognition
#   Downloading face_recognition-1.3.0-py2.py3-none-any.whl (15 kB)
# Collecting face-recognition-models>=0.3.0
#   Downloading face_recognition_models-0.3.0.tar.gz (100.1 MB)
#      |████████████████████████████████| 100.1 MB 1.2 MB/s
# Requirement already satisfied: Pillow in /usr/local/lib/python3.7/dist-packages (from face-recognition) (7.1.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from face-recognition) (1.21.6)
# Requirement already satisfied: Click>=6.0 in /usr/local/lib/python3.7/dist-packages (from face-recognition) (7.1.2)
# Requirement already satisfied: dlib>=19.7 in /usr/local/lib/python3.7/dist-packages (from face-recognition) (19.24.0)
# Building wheels for collected packages: face-recognition-models
#   Building wheel for face-recognition-models (setup.py) ... done
#   Created wheel for face-recognition-models: filename=face_recognition_models-0.3.0-py2.py3-none-any.whl size=100566185 sha256=64e295b4e309b58e2ae180c30888bf956c1447c4688b87954ba606cf3ea9a7dd
#   Stored in directory: /root/.cache/pip/wheels/d6/81/3c/884bcd5e1c120ff548d57c2ecc9ebf3281c9a6f7c0e7e7947a
# Successfully built face-recognition-models
# Installing collected packages: face-recognition-models, face-recognition
# Successfully installed face-recognition-1.3.0 face-recognition-models-0.3.0

# %% [markdown]
# ## Example 1:

# %% [markdown]
# ### Load Image

# %%
! wget https://i.pinimg.com/originals/9b/4d/e7/9b4de74326c59d27be2a19fc2ee7ca9c.jpg
# Out:
# --2022-11-14 18:13:21--  https://i.pinimg.com/originals/9b/4d/e7/9b4de74326c59d27be2a19fc2ee7ca9c.jpg
# Resolving i.pinimg.com (i.pinimg.com)... 23.64.122.72, 23.64.122.75, 2600:1417:3f::b81c:eb5b, ...
# Connecting to i.pinimg.com (i.pinimg.com)|23.64.122.72|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 105525 (103K) [image/jpeg]
# Saving to: ‘9b4de74326c59d27be2a19fc2ee7ca9c.jpg’
#
# 9b4de74326c59d27be2 100%[===================>] 103.05K  --.-KB/s    in 0.002s
#
# 2022-11-14 18:13:21 (48.7 MB/s) - ‘9b4de74326c59d27be2a19fc2ee7ca9c.jpg’ saved [105525/105525]

# %% [markdown]
# ## Find all the faces that appear in a picture:

# %%
import face_recognition
image = face_recognition.load_image_file("9b4de74326c59d27be2a19fc2ee7ca9c.jpg")
face_locations = face_recognition.face_locations(image)

# %%
face_locations
# Out:
# [(201, 498, 468, 230), (316, 786, 539, 563)]

# %%
import matplotlib.pyplot as plt

# %%
for face_location in face_locations:        
            plt.plot(face_location[1], face_location[0], 'bo')
            plt.plot(face_location[1], face_location[2], 'bo')
            plt.plot(face_location[3], face_location[2], 'bo')
            plt.plot(face_location[3], face_location[0], 'bo')

plt.imshow(image)

# %%
print(f"number of faces in the image : {len(face_locations)}")
# Out:
# number of faces in the image : 2

# %% [markdown]
# ## Example 2:

# %% [markdown]
# ### Load Image

# %%
! wget https://i.ytimg.com/vi/Ujqf6VAG8vo/maxresdefault.jpg
# Out:
# --2022-11-14 18:40:03--  https://i.ytimg.com/vi/Ujqf6VAG8vo/maxresdefault.jpg
# Resolving i.ytimg.com (i.ytimg.com)... 142.250.4.119, 74.125.24.119, 172.217.194.119, ...
# Connecting to i.ytimg.com (i.ytimg.com)|142.250.4.119|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 112183 (110K) [image/jpeg]
# Saving to: ‘maxresdefault.jpg’
#
# maxresdefault.jpg   100%[===================>] 109.55K  --.-KB/s    in 0.001s
#
# 2022-11-14 18:40:03 (127 MB/s) - ‘maxresdefault.jpg’ saved [112183/112183]

# %%
image = face_recognition.load_image_file("/content/maxresdefault.jpg")
face_locations = face_recognition.face_locations(image)
for face_location in face_locations:        
            plt.plot(face_location[1], face_location[0], 'bo')
            plt.plot(face_location[1], face_location[2], 'bo')
            plt.plot(face_location[3], face_location[2], 'bo')
            plt.plot(face_location[3], face_location[0], 'bo')

plt.imshow(image)

# %%
print(f"number of faces in the image : {len(face_locations)}")
# Out:
# number of faces in the image : 27
